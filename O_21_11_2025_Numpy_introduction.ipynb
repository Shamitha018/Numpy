# %% [markdown]
# <a href="https://colab.research.google.com/github/Shamitha018/Numpy/blob/main/O_21_11_2025_Numpy_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.0.2'

# %%
a = [10, 20, 30, 40]
b= [100, 200, 300, 400]
c=[]
for i,j in zip(a,b):
  c.append(i+j)
c
# Out:
# [110, 220, 330, 440]

# %%
l = [i+j for i,j in zip(a,b)]
l
# Out:
# [110, 220, 330, 440]

# %% [markdown]
# creating arrays using numpy

# %%
ar1 = np.array(a)
ar2 = np.array(b)
ar1, ar2
# Out:
# (array([10, 20, 30, 40]), array([100, 200, 300, 400]))

# %%
ar1+ar2
# Out:
# array([110, 220, 330, 440])

# %%
ar1-ar2
# Out:
# array([ -90, -180, -270, -360])

# %%
ar1*ar2
# Out:
# array([ 1000,  4000,  9000, 16000])

# %%
ar1/ar2
# Out:
# array([0.1, 0.1, 0.1, 0.1])

# %%
ar1%ar2
# Out:
# array([10, 20, 30, 40])

# %%
import time
start = time.time()
l1 = list(range(1,1000000))
l2 = list(range(1,1000000))
l3=[i*j for i,j in zip(l1,l2)]
end = time.time()
print(f'time taken to multiply two lists is {end-start} seconds')
# Out:
# time taken to multiply two lists is 3.520447254180908 seconds

# %%
import time
import numpy as np
start = time.time()
arr1 = np.arange(1,1000000)
arr2 = np.arange(1,1000000)
arr1 * arr2
end = time.time()
print(end-start)
# Out:
# 0.01278829574584961

# %% [markdown]
# dimensions in numpy

# %%
list1 = [1,2,3,4]
oa1 = np.array(list1)
oa1
# Out:
# array([1, 2, 3, 4])

# %%
oa1.ndim
# Out:
# 1

# %%
oa1.shape
# Out:
# (4,)

# %%
oa1.size
# Out:
# 4

# %% [markdown]
# 2d

# %%
l1 = [10,20,90]
l2 = [0,9,8]
np.array(l1,l2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1206602135.py in <cell line: 0>()
#       1 l1 = [10,20,90]
#       2 l2 = [0,9,8]
# ----> 3 np.array(l1,l2)
#
# TypeError: Field elements must be 2- or 3-tuples, got '0'

# %%
new = np.array([l1,l2])
new
# Out:
# array([[10, 20, 90],
#        [ 0,  9,  8]])

# %%
new.ndim
# Out:
# 2

# %%
new.shape
# Out:
# (2, 3)

# %%
new.size
# Out:
# 6

# %% [markdown]
# 3d

# %%
l3 = [9,8,7]
d3 = np.array([[l1,l2,l3]])
d3
# Out:
# array([[[10, 20, 90],
#         [ 0,  9,  8],
#         [ 9,  8,  7]]])

# %%
d3.ndim
# Out:
# 3

# %%
d3.shape
# Out:
# (1, 3, 3)

# %%
l = [1,2,3]
lz = [1,1,1]
nl = [l,lz]
n = np.array(nl)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4160459152.py in <cell line: 0>()
#       2 lz = [1,1,1]
#       3 n = [l,lz]
# ----> 4 n.ndim
#
# AttributeError: 'list' object has no attribute 'ndim'

# %%
l = [2,2]
l1 = [l,l]
l2= []

# %%
#2,4
l = [1,2,3,4]
l1 = [l,l]
np.array(l1).shape
# Out:
# (2, 4)

# %%
#3,3,4
l = [0,0,0,0]
l1 = [l,l,l]
l2= [l1,l1,l1]
np.array(l2).shape
# Out:
# (3, 3, 4)

# %%
#4,3,2,2
k = [1,2]
l =[k,k]
l1 = [l,l,l]
l2= [l1,l1,l1,l1]
np.array(l2).shape
# Out:
# (4, 3, 2, 2)

# %%
#5,4,3,2,1
l=[1]
l1 = [0]
l2 = [l1,l1]
l3 = [l2,l2,l2]
l4 = [l3,l3,l3,l3]
l5 = [l4,l4,l4,l4,l4]
np.array(l5).shape
# Out:
# (5, 4, 3, 2, 1)

# %%
#4,3,4,4
k = [1,2,3,4]
j = ['well', 'being', 'is', 'important']
l =[k,j]
l3 = [j,k]
l1 = [l,l3,l]
l2= [l1,l1,l1,l1]
np.array(l2).shape
# Out:
# (4, 3, 2, 4)
